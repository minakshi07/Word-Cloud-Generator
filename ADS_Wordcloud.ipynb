# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from wordcloud import WordCloud

# %%
os.getcwd()
path='C:/Users/Minakshi Kudalkar/Desktop/javafile/hash.txt'

# %%
text=open(path,'r')

# %%
data=text.read()

# %% [markdown]
# data

# %%
data
# Out:
# 'C,C++,java,HTML,javascript,jquery,python,sql,php,java,java,css,javascript,java,javascript,java,css,r,swing,unix,linux'

# %%
# %matplotlib inline

# %%
plt.figure(figsize=(20,10))
wordcloud=WordCloud(background_color="white",mode="RGB",width=2000,height=1000).generate(data)
plt.title("Random Wordcloud")
plt.imshow(wordcloud)
plt.axis("off")
plt.show()
